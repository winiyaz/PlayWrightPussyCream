# %% [markdown]
# <div style="background: black; color: #00ff00; padding: 2px; text-align: center;background-size: cover; padding: 10px; text-shadow: 00 0 20px #ec4899">
#     <h1>PAWSP - Playwright: Advanced Web Scraping in Python</h1>
#
# </div>
#
# 1. [`Colors`](https://rich.readthedocs.io/en/latest/appendix/colors.html?highlight=colors) _ list of standard colors that can be printed out
# 2. [`Ascii Banne Generator`](https://manytools.org/hacker-tools/ascii-banner/) - Used this to generate nice banners below
# 3. [`AsciiFlow`](https://asciiflow.com/#/) - Draw ASCII digrams you can then use this
#
# [Playwright: Advanced Web Scraping in Python](https://youtu.be/biFzRHk4xpY?si=6GD51NfR1L75az4f) - This Notebook will have work for this YT

# %%
# Prettification
# ------------------------------------------------------
from rich import print as rprint # For rprinting
from rich.pretty import pprint # For pretty printing
from rich import inspect # For inspect
from rich.console import Console # For console.print
from rich.markdown import Markdown # For markdown
from rich.panel import Panel # For Panel()
from rich import box # For Panel Boxes
from rich.prompt import Prompt # For Prompting 
from rich.style import Style # For styles colors
from rich.text import Text # For text Styles
console = Console() # Standard code to access console
from rich.traceback import install
install(show_locals=True)
# -------------------------------------------------------
# Out:
# <bound method InteractiveShell.excepthook of <ipykernel.zmqshell.ZMQInteractiveShell object at 0x7f3336520610>>

# %% [markdown]
# # Important Link
#
# 1. Main Vid
#
# [Playwright: Advanced Web Scraping in Python](https://youtu.be/biFzRHk4xpY?si=6GD51NfR1L75az4f) - This Notebook will have work for this YT
#
# 2. [Playwright Python](https://playwright.dev/python/docs/intro) - Official Docs
#
#
# ## General Installation notes

# %% [markdown]
# # Notebook Intro
#
# 1. This notebook is the notes as per the link mentioned above
# 2. The tut itself uses a jupyter notebook so will be doing the same thing here

# %% [markdown]
# # General Vid Notes
#
# 1. Actually a web testing framework
# 2. Useful for scraping , since it is headless. Fully contraollable
# 3. Page source gets dynamic JS for content
# 4. Need playwright
# 5. Can also do actions
# 6. Mentions that Selenium is older , and Pupetter is new also but no python bindings

# %% [markdown]
# ## Target
#
# 1. [CoinmarketCap](https://coinmarketcap.com/) - First try this then
# 2. [Coingecko](https://www.coingecko.com/) - Alternative
